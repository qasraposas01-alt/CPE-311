# %% [markdown]
# <a href="https://colab.research.google.com/github/qasraposas01-alt/CPE-311/blob/main/Seatwork_7_1_Programming_Exercise_Data_Wrangling_with_Pandas_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Hands-on Activity 7.1 Programming Exercise: Data Wrangling with Pandas - Part 1
# **
#
# ---
#
# #CPE311 Computational Thinking with Python
# Name: Raposas, Alykyne S.
#
# Section: CPE22S3
#
# Performed on: 2/24/2026
#
# Submitted on: 2/24/2-26
#
# Submitted to: Engr. Roman M. Richard

# %% [markdown]
# Using the meteorite data from the Meteorite_Landings.csv file, update the year column to only contain the year, convert it to a numeric data type, and create a new column indicating whether the meteorite was observed falling before 1970. Set the index to the id column and extract all the rows with IDs between 10,036 and 10,040 (inclusive) with loc[].
#
# >Hint 1: Use year.str.slice() to grab a substring.
#
# >Hint 2: Make sure to sort the index before using loc[] to select the range.
#
# Bonus: There's a data entry error in the year column. Can you find it? (Don't spend too much time on this.)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c0987f5a-019b-4ca5-aa72-26feb785dfe9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0987f5a-019b-4ca5-aa72-26feb785dfe9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("Meteorite_Landings.csv")
df.head()
# Out:
#        name   id nametype     recclass      mass  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong               GeoLocation
# 0    6.08333     (50.775000, 6.083330)
# 1   10.23333    (56.183330, 10.233330)
# 2 -113.00000  (54.216670, -113.000000)
# 3  -99.90000   (16.883330, -99.900000)
# 4  -64.95000  (-33.166670, -64.950000)

# %% [markdown]
# Extract Only the Year:

# %%
df['year'] = pd.to_datetime(df['year'], errors='coerce')
df['year'] = df['year'].dt.year

# %% [markdown]
# Convert Year to Numeric

# %%
df['year'] = pd.to_numeric(df['year'], errors='coerce')

# %% [markdown]
# Create New Column (Fell Before 1970)

# %%
df['fell_before_1970'] = (df['fall'] == 'Fell') & (df['year'] < 1970)

# %% [markdown]
# Set Index to id

# %%
df = df.set_index('id')

# %% [markdown]
# Sort Index

# %%
df = df.sort_index()

# %% [markdown]
# Extract IDs 10036–10040

# %%
df.loc[10036:10040]
# Out:
#             name nametype         recclass      mass   fall    year    reclat  \
# id
# 10036     Enigma    Valid               H4      94.0  Found  1970.0  31.33333
# 10037       Enon    Valid  Iron, ungrouped     763.0  Found  1970.0  39.86667
# 10038      Enshi    Valid               H5    8000.0   Fell  1970.0  30.30000
# 10039  Ensisheim    Valid              LL6  127000.0   Fell  1970.0  47.86667
#
#          reclong              GeoLocation  fell_before_1970
# id
# 10036  -82.31667  (31.333330, -82.316670)             False
# 10037  -83.95000  (39.866670, -83.950000)             False
# 10038  109.50000  (30.300000, 109.500000)             False
# 10039    7.35000    (47.866670, 7.350000)             False

# %% [markdown]
# Find the Year Data Error

# %%
df[df['year'].isna()]
# Out:
#                         name nametype        recclass      mass   fall  year  \
# id
# 2344         Asarco Mexicana    Valid     Iron, IIIAB       NaN  Found   NaN
# 4902                     Aus    Valid               L      30.2  Found   NaN
# 5012             Benares (b)    Valid            Iron       NaN  Found   NaN
# 5191              Cacilandia    Valid              H6       NaN  Found   NaN
# 5199              California    Valid   Iron, IAB-sLL       NaN  Found   NaN
# ...                      ...      ...             ...       ...    ...   ...
# 56528  Jiddat al Harasis 796    Valid              L5      22.8  Found   NaN
# 56529       Jiddat Arkad 003    Valid              L5     148.0  Found   NaN
# 56530  Jiddat al Harasis 797    Valid              L5     249.0  Found   NaN
# 56566              Elizabeth    Valid   Iron, IAB-ung     732.0  Found   NaN
# 56567             Karavannoe    Valid  Pallasite, PES  132000.0  Found   NaN
#
# ...
